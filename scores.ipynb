# %% [markdown]
# ## Loading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# This CSV comes from the Louisville Metro Open Data website. It is info on food establishments that have passing health department scores.

# %%
passing_df = pd.read_csv('Louisville_Metro_KY_-_Restaurant_Inspection_Scores.csv')
passing_df
# Out:
#        EstablishmentID  InspectionID Ins_TypeDesc          EstablishmentName  \
# 0                29956       1684470      REGULAR                  CVS #6211
# 1                29967       1699737      REGULAR     NEIGHBORHOOD FOOD MART
# 2                29979       1698679      REGULAR          CIRCLE K #4700075
# 3                29979       1698680      REGULAR          CIRCLE K #4700075
# 4                29979       1731827      REGULAR          CIRCLE K #4700075
# ...                ...           ...          ...                        ...
# 11230           117776       1740271        OTHER  SNOW FRUIT @ KROGER L-379
# 11231           117778       1740274        OTHER                    SMILEYS
# 11232           117778       1740281        OTHER                    SMILEYS
# 11233           117788       1740679        OTHER    PRINCESS AND THE POPPER
# 11234           117819       1741889        OTHER            DOGGY DOG WORLD
#
#        PlaceName                Address  Address2        City State    Zip  \
# 0            NaN      3721 LEXINGTON RD       NaN  LOUISVILLE    KY  40207
# 1            NaN         542 LAMPTON ST       NaN  LOUISVILLE    KY  40203
# 2            NaN         1630 ARTHUR ST       NaN  LOUISVILLE    KY  40208
# 3            NaN         1630 ARTHUR ST       NaN  LOUISVILLE    KY  40208
# 4            NaN         1630 ARTHUR ST       NaN  LOUISVILLE    KY  40208
# ...          ...                    ...       ...         ...   ...    ...
# 11230        NaN   9080 TAYLORSVILLE RD       NaN  LOUISVILLE    KY  40299
# 11231        NaN  3905 NEWBURG RD STE B       NaN  LOUISVILLE    KY  40218
# 11232        NaN  3905 NEWBURG RD STE B       NaN  LOUISVILLE    KY  40218
# 11233        NaN                    NaN       NaN  LOUISVILLE    KY  40202
# 11234        NaN                    NaN       NaN  LOUISVILLE    KY  40202
#
#                          TypeDescription       InspectionDate  score Grade  \
# 0                    PRE-PACKAGED RETAIL  2022/07/06 00:00:00    100   NaN
# 1            SUPERMARKET WITH PROCESSING  2022/09/07 00:00:00     97   NaN
# 2      RETAIL-FOOD  10,000 SQ FT OR LESS  2022/09/01 00:00:00     97     A
# 3      RETAIL-FOOD  10,000 SQ FT OR LESS  2022/09/01 00:00:00     98   NaN
# 4      RETAIL-FOOD  10,000 SQ FT OR LESS  2023/01/27 00:00:00     95     A
# ...                                  ...                  ...    ...   ...
# 11230                       FOOD SERVICE  2023/02/24 00:00:00    100   NaN
# 11231  RETAIL-FOOD  10,000 SQ FT OR LESS  2023/02/27 00:00:00     99   NaN
# 11232  RETAIL-FOOD  10,000 SQ FT OR LESS  2023/02/27 00:00:00     99   NaN
# 11233       MOBILE RESTRICTED CONCESSION  2023/03/10 00:00:00    100   NaN
# 11234       MOBILE RESTRICTED CONCESSION  2023/03/16 00:00:00    100   NaN
#
#                       NameSearch  Intersection  ObjectId
# 0                      CVS #6211           NaN         1
# 1         NEIGHBORHOOD FOOD MART           NaN         2
# 2              CIRCLE K #4700075           NaN         3
# 3              CIRCLE K #4700075           NaN         4
# 4              CIRCLE K #4700075           NaN         5
# ...                          ...           ...       ...
# 11230  SNOW FRUIT @ KROGER L-379           NaN     11231
# 11231                    SMILEYS           NaN     11232
# 11232                    SMILEYS           NaN     11233
# 11233    PRINCESS AND THE POPPER           NaN     11234
# 11234            DOGGY DOG WORLD           NaN     11235
#
# [11235 rows x 17 columns]

# %% [markdown]
# This is a separate CSV from the Louisville Metro Open Data website. This is a list of only the businesses that had a failing health department score.

# %%
failed_df = pd.read_csv('Louisville_Metro_KY_-_Inspection_Violations_of_Failed_Restaurants.csv')
failed_df
# Out:
#       EstablishmentID          InspectionDate  InspectionID  \
# 0               91975  2018/04/23 04:00:00+00       1373797
# 1               91975  2018/04/23 04:00:00+00       1373797
# 2               91975  2018/04/23 04:00:00+00       1373797
# 3               91975  2018/04/23 04:00:00+00       1373797
# 4               91975  2018/04/23 04:00:00+00       1373797
# ...               ...                     ...           ...
# 3771            32754  2023/02/01 05:00:00+00       1732664
# 3772            32754  2023/02/01 05:00:00+00       1732664
# 3773            68661  2023/01/03 05:00:00+00       1726425
# 3774            92375  2023/03/01 05:00:00+00       1738759
# 3775            92375  2023/03/01 05:00:00+00       1738759
#
#                            EstTypeDesc          premise_name premise_adr1_num  \
# 0                         FOOD SERVICE          RIVIERA MAYA             8104
# 1                         FOOD SERVICE          RIVIERA MAYA             8104
# 2                         FOOD SERVICE          RIVIERA MAYA             8104
# 3                         FOOD SERVICE          RIVIERA MAYA             8104
# 4                         FOOD SERVICE          RIVIERA MAYA             8104
# ...                                ...                   ...              ...
# 3771  SCHOOL CAFETERIA OR FOOD SERVICE   CENTRAL HIGH SCHOOL             1130
# 3772  SCHOOL CAFETERIA OR FOOD SERVICE   CENTRAL HIGH SCHOOL             1130
# 3773                      FOOD SERVICE  BONEFISH GRILL #7801              657
# 3774                      FOOD SERVICE       CHINA ONE ZHENG              816
# 3775                      FOOD SERVICE       CHINA ONE ZHENG              816
#
#      premise_adr1_street premise_city premise_state  premise_zip  \
# 0      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 1      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 2      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 3      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 4      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# ...                  ...          ...           ...          ...
# 3771       W CHESTNUT ST   LOUISVILLE            KY        40203
# 3772       W CHESTNUT ST   LOUISVILLE            KY        40203
# 3773  S HURSTBOURNE PKWY   LOUISVILLE            KY        40222
# 3774        EASTERN PKWY   LOUISVILLE            KY        40217
# 3775        EASTERN PKWY   LOUISVILLE            KY        40217
#
#      InspectionType  score  InspTypeSpecificViolID  \
# 0           REGULAR     78                       3
# 1           REGULAR     78                       6
# 2           REGULAR     78                      33
# 3           REGULAR     78                       8
# 4           REGULAR     78                      11
# ...             ...    ...                     ...
# 3771        REGULAR     87                      21
# 3772        REGULAR     87                      29
# 3773        REGULAR     96                      21
# 3774        REGULAR     88                      53
# 3775        REGULAR     88                      25
#
#                                           ViolationDesc critical_yn  \
# 0                 POTENTIALLY HAZARDOUS FOOD-SAFE TEMP.         Yes
# 1            Potentially hazardous food properly thawed          No
# 2            TOXIC ITEMS PROPERLY STORED, LABELED, USED         Yes
# 3     Food Protection - storage, prep, display, serv...          No
# 4     HANDS WASHED AND CLEAN,HYGIENIC PRACTICES PREV...         Yes
# ...                                                 ...         ...
# 3771                   PROPER COLD HOLDING TEMPERATURES         Yes
# 3772  TOXIC SUBSTANCES PROPERLY IDENTIFIED, STORED, ...         Yes
# 3773                   PROPER COLD HOLDING TEMPERATURES         Yes
# 3774            SEWAGE AND WASTEWATER PROPERLY DISPOSED         Yes
# 3775                PROPER DATE MARKING AND DISPOSITION         Yes
#
#                                      Insp_Viol_Comments rpt_area_id  ObjectId
# 0     Potentially hazardous food requiring refrigera...         605         1
# 1     Improper thawing methods being used for potent...         605         2
# 2     Toxic items not properly stored. (next to food...         605         3
# 3     Food not stored at least 6`` off the floor.  F...         605         4
# 4     Improper storage of employee food/drink(s). (i...         605         5
# ...                                                 ...         ...       ...
# 3771  TCS food not maintained at 5°C (41°F) or below...         605      3772
# 3772  Improper storage of poisonous or toxic materia...         605      3773
# 3773  TCS food not maintained at 5°C (41°F) or below...         605      3774
# 3774     rear hand sink drain line backflows onto floor         605      3775
# 3775  prepared food items not properly date marked  ...         605      3776
#
# [3776 rows x 18 columns]

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# Dropping uneeded and redundant columns:

# %%
passing_df.drop(['PlaceName', 'Address2', 'Intersection', 'ObjectId', 'NameSearch'], axis='columns', inplace=True)
passing_df
# Out:
#        EstablishmentID  InspectionID Ins_TypeDesc          EstablishmentName  \
# 0                29956       1684470      REGULAR                  CVS #6211
# 1                29967       1699737      REGULAR     NEIGHBORHOOD FOOD MART
# 2                29979       1698679      REGULAR          CIRCLE K #4700075
# 3                29979       1698680      REGULAR          CIRCLE K #4700075
# 4                29979       1731827      REGULAR          CIRCLE K #4700075
# ...                ...           ...          ...                        ...
# 11230           117776       1740271        OTHER  SNOW FRUIT @ KROGER L-379
# 11231           117778       1740274        OTHER                    SMILEYS
# 11232           117778       1740281        OTHER                    SMILEYS
# 11233           117788       1740679        OTHER    PRINCESS AND THE POPPER
# 11234           117819       1741889        OTHER            DOGGY DOG WORLD
#
#                      Address        City State    Zip  \
# 0          3721 LEXINGTON RD  LOUISVILLE    KY  40207
# 1             542 LAMPTON ST  LOUISVILLE    KY  40203
# 2             1630 ARTHUR ST  LOUISVILLE    KY  40208
# 3             1630 ARTHUR ST  LOUISVILLE    KY  40208
# 4             1630 ARTHUR ST  LOUISVILLE    KY  40208
# ...                      ...         ...   ...    ...
# 11230   9080 TAYLORSVILLE RD  LOUISVILLE    KY  40299
# 11231  3905 NEWBURG RD STE B  LOUISVILLE    KY  40218
# 11232  3905 NEWBURG RD STE B  LOUISVILLE    KY  40218
# 11233                    NaN  LOUISVILLE    KY  40202
# 11234                    NaN  LOUISVILLE    KY  40202
#
#                          TypeDescription       InspectionDate  score Grade
# 0                    PRE-PACKAGED RETAIL  2022/07/06 00:00:00    100   NaN
# 1            SUPERMARKET WITH PROCESSING  2022/09/07 00:00:00     97   NaN
# 2      RETAIL-FOOD  10,000 SQ FT OR LESS  2022/09/01 00:00:00     97     A
# 3      RETAIL-FOOD  10,000 SQ FT OR LESS  2022/09/01 00:00:00     98   NaN
# 4      RETAIL-FOOD  10,000 SQ FT OR LESS  2023/01/27 00:00:00     95     A
# ...                                  ...                  ...    ...   ...
# 11230                       FOOD SERVICE  2023/02/24 00:00:00    100   NaN
# 11231  RETAIL-FOOD  10,000 SQ FT OR LESS  2023/02/27 00:00:00     99   NaN
# 11232  RETAIL-FOOD  10,000 SQ FT OR LESS  2023/02/27 00:00:00     99   NaN
# 11233       MOBILE RESTRICTED CONCESSION  2023/03/10 00:00:00    100   NaN
# 11234       MOBILE RESTRICTED CONCESSION  2023/03/16 00:00:00    100   NaN
#
# [11235 rows x 12 columns]

# %% [markdown]
# Weeding out locations such as schools, convience stores, etc:

# %%
passing_food = passing_df.query("TypeDescription == 'FOOD SERVICE'")
passing_food
# Out:
#        EstablishmentID  InspectionID Ins_TypeDesc  \
# 50               31334       1722999      REGULAR
# 122              32112       1674538      REGULAR
# 123              32112       1723406      REGULAR
# 124              32114       1673620      REGULAR
# 126              32114       1720399      REGULAR
# ...                ...           ...          ...
# 11222           117748       1742334      REGULAR
# 11223           117748       1739676        OTHER
# 11225           117751       1739696        OTHER
# 11226           117752       1739711        OTHER
# 11230           117776       1740271        OTHER
#
#                  EstablishmentName                   Address        City  \
# 50                  GOOD SAMARITAN   3500 GOOD SAMARITAN WAY  LOUISVILLE
# 122                    CHEDDAR BOX     3909 CHENOWETH SQUARE  LOUISVILLE
# 123                    CHEDDAR BOX     3909 CHENOWETH SQUARE  LOUISVILLE
# 124         CORNER CAFE & PIZZERIA      9307 NEW LAGRANGE RD  LOUISVILLE
# 126         CORNER CAFE & PIZZERIA      9307 NEW LAGRANGE RD  LOUISVILLE
# ...                            ...                       ...         ...
# 11222                  MAMA SHADIA          2300 W MARKET ST  LOUISVILLE
# 11223                  MAMA SHADIA          2300 W MARKET ST  LOUISVILLE
# 11225  TOMO JAPANESE RAMEN & SUSHI       5023 MUD LN STE 160  LOUISVILLE
# 11226           KAI'MACS HOTPLATES  1812 W MUHAMMAD ALI BLVD  LOUISVILLE
# 11230    SNOW FRUIT @ KROGER L-379      9080 TAYLORSVILLE RD  LOUISVILLE
#
#       State    Zip TypeDescription       InspectionDate  score Grade
# 50       KY  40299    FOOD SERVICE  2022/12/12 00:00:00     99     A
# 122      KY  40207    FOOD SERVICE  2022/05/24 00:00:00     96     A
# 123      KY  40207    FOOD SERVICE  2022/12/13 00:00:00     96     A
# 124      KY  40242    FOOD SERVICE  2022/05/19 00:00:00     93     A
# 126      KY  40242    FOOD SERVICE  2022/12/01 00:00:00     93     A
# ...     ...    ...             ...                  ...    ...   ...
# 11222    KY  40212    FOOD SERVICE  2023/03/17 00:00:00     97     A
# 11223    KY  40212    FOOD SERVICE  2023/02/15 00:00:00     99   NaN
# 11225    KY  40229    FOOD SERVICE  2023/02/20 00:00:00     98   NaN
# 11226    KY  40203    FOOD SERVICE  2023/02/21 00:00:00    100   NaN
# 11230    KY  40299    FOOD SERVICE  2023/02/24 00:00:00    100   NaN
#
# [5681 rows x 12 columns]

# %% [markdown]
# Weeding out uneeded columns:

# %%
failed_df.drop(['rpt_area_id','ObjectId'], axis='columns', inplace=True)
failed_df
# Out:
#       EstablishmentID          InspectionDate  InspectionID  \
# 0               91975  2018/04/23 04:00:00+00       1373797
# 1               91975  2018/04/23 04:00:00+00       1373797
# 2               91975  2018/04/23 04:00:00+00       1373797
# 3               91975  2018/04/23 04:00:00+00       1373797
# 4               91975  2018/04/23 04:00:00+00       1373797
# ...               ...                     ...           ...
# 3771            32754  2023/02/01 05:00:00+00       1732664
# 3772            32754  2023/02/01 05:00:00+00       1732664
# 3773            68661  2023/01/03 05:00:00+00       1726425
# 3774            92375  2023/03/01 05:00:00+00       1738759
# 3775            92375  2023/03/01 05:00:00+00       1738759
#
#                            EstTypeDesc          premise_name premise_adr1_num  \
# 0                         FOOD SERVICE          RIVIERA MAYA             8104
# 1                         FOOD SERVICE          RIVIERA MAYA             8104
# 2                         FOOD SERVICE          RIVIERA MAYA             8104
# 3                         FOOD SERVICE          RIVIERA MAYA             8104
# 4                         FOOD SERVICE          RIVIERA MAYA             8104
# ...                                ...                   ...              ...
# 3771  SCHOOL CAFETERIA OR FOOD SERVICE   CENTRAL HIGH SCHOOL             1130
# 3772  SCHOOL CAFETERIA OR FOOD SERVICE   CENTRAL HIGH SCHOOL             1130
# 3773                      FOOD SERVICE  BONEFISH GRILL #7801              657
# 3774                      FOOD SERVICE       CHINA ONE ZHENG              816
# 3775                      FOOD SERVICE       CHINA ONE ZHENG              816
#
#      premise_adr1_street premise_city premise_state  premise_zip  \
# 0      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 1      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 2      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 3      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 4      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# ...                  ...          ...           ...          ...
# 3771       W CHESTNUT ST   LOUISVILLE            KY        40203
# 3772       W CHESTNUT ST   LOUISVILLE            KY        40203
# 3773  S HURSTBOURNE PKWY   LOUISVILLE            KY        40222
# 3774        EASTERN PKWY   LOUISVILLE            KY        40217
# 3775        EASTERN PKWY   LOUISVILLE            KY        40217
#
#      InspectionType  score  InspTypeSpecificViolID  \
# 0           REGULAR     78                       3
# 1           REGULAR     78                       6
# 2           REGULAR     78                      33
# 3           REGULAR     78                       8
# 4           REGULAR     78                      11
# ...             ...    ...                     ...
# 3771        REGULAR     87                      21
# 3772        REGULAR     87                      29
# 3773        REGULAR     96                      21
# 3774        REGULAR     88                      53
# 3775        REGULAR     88                      25
#
#                                           ViolationDesc critical_yn  \
# 0                 POTENTIALLY HAZARDOUS FOOD-SAFE TEMP.         Yes
# 1            Potentially hazardous food properly thawed          No
# 2            TOXIC ITEMS PROPERLY STORED, LABELED, USED         Yes
# 3     Food Protection - storage, prep, display, serv...          No
# 4     HANDS WASHED AND CLEAN,HYGIENIC PRACTICES PREV...         Yes
# ...                                                 ...         ...
# 3771                   PROPER COLD HOLDING TEMPERATURES         Yes
# 3772  TOXIC SUBSTANCES PROPERLY IDENTIFIED, STORED, ...         Yes
# 3773                   PROPER COLD HOLDING TEMPERATURES         Yes
# 3774            SEWAGE AND WASTEWATER PROPERLY DISPOSED         Yes
# 3775                PROPER DATE MARKING AND DISPOSITION         Yes
#
#                                      Insp_Viol_Comments
# 0     Potentially hazardous food requiring refrigera...
# 1     Improper thawing methods being used for potent...
# 2     Toxic items not properly stored. (next to food...
# 3     Food not stored at least 6`` off the floor.  F...
# 4     Improper storage of employee food/drink(s). (i...
# ...                                                 ...
# 3771  TCS food not maintained at 5°C (41°F) or below...
# 3772  Improper storage of poisonous or toxic materia...
# 3773  TCS food not maintained at 5°C (41°F) or below...
# 3774     rear hand sink drain line backflows onto floor
# 3775  prepared food items not properly date marked  ...
#
# [3776 rows x 16 columns]

# %%
failed_df['Address'] = failed_df['premise_adr1_num'].map(str) + ' ' + failed_df['premise_adr1_street'].map(str)
failed_df
# Out:
#       EstablishmentID          InspectionDate  InspectionID  \
# 0               91975  2018/04/23 04:00:00+00       1373797
# 1               91975  2018/04/23 04:00:00+00       1373797
# 2               91975  2018/04/23 04:00:00+00       1373797
# 3               91975  2018/04/23 04:00:00+00       1373797
# 4               91975  2018/04/23 04:00:00+00       1373797
# ...               ...                     ...           ...
# 3771            32754  2023/02/01 05:00:00+00       1732664
# 3772            32754  2023/02/01 05:00:00+00       1732664
# 3773            68661  2023/01/03 05:00:00+00       1726425
# 3774            92375  2023/03/01 05:00:00+00       1738759
# 3775            92375  2023/03/01 05:00:00+00       1738759
#
#                            EstTypeDesc          premise_name premise_adr1_num  \
# 0                         FOOD SERVICE          RIVIERA MAYA             8104
# 1                         FOOD SERVICE          RIVIERA MAYA             8104
# 2                         FOOD SERVICE          RIVIERA MAYA             8104
# 3                         FOOD SERVICE          RIVIERA MAYA             8104
# 4                         FOOD SERVICE          RIVIERA MAYA             8104
# ...                                ...                   ...              ...
# 3771  SCHOOL CAFETERIA OR FOOD SERVICE   CENTRAL HIGH SCHOOL             1130
# 3772  SCHOOL CAFETERIA OR FOOD SERVICE   CENTRAL HIGH SCHOOL             1130
# 3773                      FOOD SERVICE  BONEFISH GRILL #7801              657
# 3774                      FOOD SERVICE       CHINA ONE ZHENG              816
# 3775                      FOOD SERVICE       CHINA ONE ZHENG              816
#
#      premise_adr1_street premise_city premise_state  premise_zip  \
# 0      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 1      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 2      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 3      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# 4      NATIONAL TURNPIKE   LOUISVILLE            KY        40214
# ...                  ...          ...           ...          ...
# 3771       W CHESTNUT ST   LOUISVILLE            KY        40203
# 3772       W CHESTNUT ST   LOUISVILLE            KY        40203
# 3773  S HURSTBOURNE PKWY   LOUISVILLE            KY        40222
# 3774        EASTERN PKWY   LOUISVILLE            KY        40217
# 3775        EASTERN PKWY   LOUISVILLE            KY        40217
#
#      InspectionType  score  InspTypeSpecificViolID  \
# 0           REGULAR     78                       3
# 1           REGULAR     78                       6
# 2           REGULAR     78                      33
# 3           REGULAR     78                       8
# 4           REGULAR     78                      11
# ...             ...    ...                     ...
# 3771        REGULAR     87                      21
# 3772        REGULAR     87                      29
# 3773        REGULAR     96                      21
# 3774        REGULAR     88                      53
# 3775        REGULAR     88                      25
#
#                                           ViolationDesc critical_yn  \
# 0                 POTENTIALLY HAZARDOUS FOOD-SAFE TEMP.         Yes
# 1            Potentially hazardous food properly thawed          No
# 2            TOXIC ITEMS PROPERLY STORED, LABELED, USED         Yes
# 3     Food Protection - storage, prep, display, serv...          No
# 4     HANDS WASHED AND CLEAN,HYGIENIC PRACTICES PREV...         Yes
# ...                                                 ...         ...
# 3771                   PROPER COLD HOLDING TEMPERATURES         Yes
# 3772  TOXIC SUBSTANCES PROPERLY IDENTIFIED, STORED, ...         Yes
# 3773                   PROPER COLD HOLDING TEMPERATURES         Yes
# 3774            SEWAGE AND WASTEWATER PROPERLY DISPOSED         Yes
# 3775                PROPER DATE MARKING AND DISPOSITION         Yes
#
#                                      Insp_Viol_Comments  \
# 0     Potentially hazardous food requiring refrigera...
# 1     Improper thawing methods being used for potent...
# 2     Toxic items not properly stored. (next to food...
# 3     Food not stored at least 6`` off the floor.  F...
# 4     Improper storage of employee food/drink(s). (i...
# ...                                                 ...
# 3771  TCS food not maintained at 5°C (41°F) or below...
# 3772  Improper storage of poisonous or toxic materia...
# 3773  TCS food not maintained at 5°C (41°F) or below...
# 3774     rear hand sink drain line backflows onto floor
# 3775  prepared food items not properly date marked  ...
#
#                      Address
# 0     8104 NATIONAL TURNPIKE
# 1     8104 NATIONAL TURNPIKE
# 2     8104 NATIONAL TURNPIKE
# 3     8104 NATIONAL TURNPIKE
# 4     8104 NATIONAL TURNPIKE
# ...                      ...
# 3771      1130 W CHESTNUT ST
# 3772      1130 W CHESTNUT ST
# 3773  657 S HURSTBOURNE PKWY
# 3774        816 EASTERN PKWY
# 3775        816 EASTERN PKWY
#
# [3776 rows x 17 columns]

# %% [markdown]
# Only focusing on food service locations:

# %%
failed_food = failed_df.query("EstTypeDesc == 'FOOD SERVICE'")
failed_food
# Out:
#       EstablishmentID          InspectionDate  InspectionID   EstTypeDesc  \
# 0               91975  2018/04/23 04:00:00+00       1373797  FOOD SERVICE
# 1               91975  2018/04/23 04:00:00+00       1373797  FOOD SERVICE
# 2               91975  2018/04/23 04:00:00+00       1373797  FOOD SERVICE
# 3               91975  2018/04/23 04:00:00+00       1373797  FOOD SERVICE
# 4               91975  2018/04/23 04:00:00+00       1373797  FOOD SERVICE
# ...               ...                     ...           ...           ...
# 3763            96120  2023/02/15 05:00:00+00       1735402  FOOD SERVICE
# 3768           104879  2022/11/09 05:00:00+00       1716260  FOOD SERVICE
# 3773            68661  2023/01/03 05:00:00+00       1726425  FOOD SERVICE
# 3774            92375  2023/03/01 05:00:00+00       1738759  FOOD SERVICE
# 3775            92375  2023/03/01 05:00:00+00       1738759  FOOD SERVICE
#
#                 premise_name premise_adr1_num premise_adr1_street  \
# 0               RIVIERA MAYA             8104   NATIONAL TURNPIKE
# 1               RIVIERA MAYA             8104   NATIONAL TURNPIKE
# 2               RIVIERA MAYA             8104   NATIONAL TURNPIKE
# 3               RIVIERA MAYA             8104   NATIONAL TURNPIKE
# 4               RIVIERA MAYA             8104   NATIONAL TURNPIKE
# ...                      ...              ...                 ...
# 3763                 HOOTERS             4948           DIXIE HWY
# 3768  STARTING GATE PANTRY 5              700         CENTRAL AVE
# 3773    BONEFISH GRILL #7801              657  S HURSTBOURNE PKWY
# 3774         CHINA ONE ZHENG              816        EASTERN PKWY
# 3775         CHINA ONE ZHENG              816        EASTERN PKWY
#
#      premise_city premise_state  premise_zip InspectionType  score  \
# 0      LOUISVILLE            KY        40214        REGULAR     78
# 1      LOUISVILLE            KY        40214        REGULAR     78
# 2      LOUISVILLE            KY        40214        REGULAR     78
# 3      LOUISVILLE            KY        40214        REGULAR     78
# 4      LOUISVILLE            KY        40214        REGULAR     78
# ...           ...           ...          ...            ...    ...
# 3763   LOUISVILLE            KY        40216        REGULAR     90
# 3768   LOUISVILLE            KY        40208        REGULAR     96
# 3773   LOUISVILLE            KY        40222        REGULAR     96
# 3774   LOUISVILLE            KY        40217        REGULAR     88
# 3775   LOUISVILLE            KY        40217        REGULAR     88
#
#       InspTypeSpecificViolID  \
# 0                          3
# 1                          6
# 2                         33
# 3                          8
# 4                         11
# ...                      ...
# 3763                      23
# 3768                      18
# 3773                      21
# 3774                      53
# 3775                      25
#
#                                           ViolationDesc critical_yn  \
# 0                 POTENTIALLY HAZARDOUS FOOD-SAFE TEMP.         Yes
# 1            Potentially hazardous food properly thawed          No
# 2            TOXIC ITEMS PROPERLY STORED, LABELED, USED         Yes
# 3     Food Protection - storage, prep, display, serv...          No
# 4     HANDS WASHED AND CLEAN,HYGIENIC PRACTICES PREV...         Yes
# ...                                                 ...         ...
# 3763                PROPER COOLING TIME AND TEMPERATURE         Yes
# 3768      FOOD-CONTACT SURFACES:  CLEANED AND SANITIZED         Yes
# 3773                   PROPER COLD HOLDING TEMPERATURES         Yes
# 3774            SEWAGE AND WASTEWATER PROPERLY DISPOSED         Yes
# 3775                PROPER DATE MARKING AND DISPOSITION         Yes
#
#                                      Insp_Viol_Comments  \
# 0     Potentially hazardous food requiring refrigera...
# 1     Improper thawing methods being used for potent...
# 2     Toxic items not properly stored. (next to food...
# 3     Food not stored at least 6`` off the floor.  F...
# 4     Improper storage of employee food/drink(s). (i...
# ...                                                 ...
# 3763                 roasted wings not cooled properly
# 3768  Dishwasher final rinse not reaching 180 degree...
# 3773  TCS food not maintained at 5°C (41°F) or below...
# 3774     rear hand sink drain line backflows onto floor
# 3775  prepared food items not properly date marked  ...
#
#                      Address
# 0     8104 NATIONAL TURNPIKE
# 1     8104 NATIONAL TURNPIKE
# 2     8104 NATIONAL TURNPIKE
# 3     8104 NATIONAL TURNPIKE
# 4     8104 NATIONAL TURNPIKE
# ...                      ...
# 3763          4948 DIXIE HWY
# 3768         700 CENTRAL AVE
# 3773  657 S HURSTBOURNE PKWY
# 3774        816 EASTERN PKWY
# 3775        816 EASTERN PKWY
#
# [3359 rows x 17 columns]

# %% [markdown]
# ## Merging Data

# %%
####inner join####
merged = pd.merge(passing_food,failed_food,on='EstablishmentID',how='inner')
merged
# Out:
#        EstablishmentID  InspectionID_x Ins_TypeDesc    EstablishmentName  \
# 0                32112         1674538      REGULAR          CHEDDAR BOX
# 1                32112         1674538      REGULAR          CHEDDAR BOX
# 2                32112         1674538      REGULAR          CHEDDAR BOX
# 3                32112         1674538      REGULAR          CHEDDAR BOX
# 4                32112         1723406      REGULAR          CHEDDAR BOX
# ...                ...             ...          ...                  ...
# 11446           116872         1721898      REGULAR  VIRTUE BAR & LOUNGE
# 11447           116872         1721898      REGULAR  VIRTUE BAR & LOUNGE
# 11448           116872         1721898      REGULAR  VIRTUE BAR & LOUNGE
# 11449           116872         1721898      REGULAR  VIRTUE BAR & LOUNGE
# 11450           116872         1721898      REGULAR  VIRTUE BAR & LOUNGE
#
#                    Address_x        City State    Zip TypeDescription  \
# 0      3909 CHENOWETH SQUARE  LOUISVILLE    KY  40207    FOOD SERVICE
# 1      3909 CHENOWETH SQUARE  LOUISVILLE    KY  40207    FOOD SERVICE
# 2      3909 CHENOWETH SQUARE  LOUISVILLE    KY  40207    FOOD SERVICE
# 3      3909 CHENOWETH SQUARE  LOUISVILLE    KY  40207    FOOD SERVICE
# 4      3909 CHENOWETH SQUARE  LOUISVILLE    KY  40207    FOOD SERVICE
# ...                      ...         ...   ...    ...             ...
# 11446     1971 BROWNSBORO RD  LOUISVILLE    KY  40206    FOOD SERVICE
# 11447     1971 BROWNSBORO RD  LOUISVILLE    KY  40206    FOOD SERVICE
# 11448     1971 BROWNSBORO RD  LOUISVILLE    KY  40206    FOOD SERVICE
# 11449     1971 BROWNSBORO RD  LOUISVILLE    KY  40206    FOOD SERVICE
# 11450     1971 BROWNSBORO RD  LOUISVILLE    KY  40206    FOOD SERVICE
#
#           InspectionDate_x  ...  premise_city premise_state premise_zip  \
# 0      2022/05/24 00:00:00  ...    LOUISVILLE            KY       40207
# 1      2022/05/24 00:00:00  ...    LOUISVILLE            KY       40207
# 2      2022/05/24 00:00:00  ...    LOUISVILLE            KY       40207
# 3      2022/05/24 00:00:00  ...    LOUISVILLE            KY       40207
# 4      2022/12/13 00:00:00  ...    LOUISVILLE            KY       40207
# ...                    ...  ...           ...           ...         ...
# 11446  2022/12/07 00:00:00  ...    LOUISVILLE            KY       40206
# 11447  2022/12/07 00:00:00  ...    LOUISVILLE            KY       40206
# 11448  2022/12/07 00:00:00  ...    LOUISVILLE            KY       40206
# 11449  2022/12/07 00:00:00  ...    LOUISVILLE            KY       40206
# 11450  2022/12/07 00:00:00  ...    LOUISVILLE            KY       40206
#
#        InspectionType score_y InspTypeSpecificViolID  \
# 0             REGULAR      87                     18
# 1             REGULAR      87                     21
# 2             REGULAR      87                     29
# 3             REGULAR      87                     23
# 4             REGULAR      87                     18
# ...               ...     ...                    ...
# 11446         REGULAR      83                     44
# 11447         REGULAR      83                     47
# 11448         REGULAR      83                     49
# 11449         REGULAR      83                     56
# 11450         REGULAR      83                     51
#
#                                            ViolationDesc critical_yn  \
# 0          FOOD-CONTACT SURFACES:  CLEANED AND SANITIZED         Yes
# 1                       PROPER COLD HOLDING TEMPERATURES         Yes
# 2      TOXIC SUBSTANCES PROPERLY IDENTIFIED, STORED, ...         Yes
# 3                    PROPER COOLING TIME AND TEMPERATURE         Yes
# 4          FOOD-CONTACT SURFACES:  CLEANED AND SANITIZED         Yes
# ...                                                  ...         ...
# 11446                   In-use utensils, properly stored          No
# 11447                               GLOVES USED PROPERLY         Yes
# 11448  Ware washing facilities:  installed, maintaine...          No
# 11449  Physical facilities installed, maintained and ...          No
# 11450  Hot and cold water available; adequate pressur...          No
#
#                                       Insp_Viol_Comments  \
# 0      Food-contact surfaces not cleaned and sanitize...
# 1      TCS food not maintained at 5°C (41°F) or below...
# 2                          Toxic chemicals not labeled.
# 3      TCS food requiring refrigeration not rapidly c...
# 4      Food-contact surfaces not cleaned and sanitize...
# ...                                                  ...
# 11446  In-use food dispensing utensils not properly s...
# 11447             Hands not washed when changing gloves.
# 11448  Test strips for dishwasher sanitizer not provi...
# 11449  Employee personal items are not properly store...
# 11450  Excessive condensate (ice) build-up in reach-i...
#
#                    Address_y
# 0      3909 CHENOWETH SQUARE
# 1      3909 CHENOWETH SQUARE
# 2      3909 CHENOWETH SQUARE
# 3      3909 CHENOWETH SQUARE
# 4      3909 CHENOWETH SQUARE
# ...                      ...
# 11446     1971 BROWNSBORO RD
# 11447     1971 BROWNSBORO RD
# 11448     1971 BROWNSBORO RD
# 11449     1971 BROWNSBORO RD
# 11450     1971 BROWNSBORO RD
#
# [11451 rows x 28 columns]

# %%
#full join
merged2 = pd.merge(passing_clean,failed,on='EstablishmentID',how='outer',indicator=True)
merged2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 #full join
# ----> 2 merged2 = pd.merge(passing_clean,failed,on='EstablishmentID',how='outer',indicator=True)
#       3 merged2
#
# NameError: name 'passing_clean' is not defined

# %%
#left join
#pd.merge(passing_clean,failed,on='EstablishmentID',how='left')

# %%
#merged = pd.merge(passing_clean, failed, on='EstablishmentID')
#merged
